# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
from solvers import * #solve_sir, solve_lv, solve_sir_lv, solve_sir_lv_control

# %%
from plot import * #plot_sir, plot_lv, plot_sir_lv, plot_limit_cycle, plot_beta_I

# %% [markdown]
# ### Initial conditions

# %%
N = 13000000
R0 = 200000
I0 = 200000
r = 3e-1
e = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
Istar = r/e
Jstar = gamma*N

# %% [markdown]
# ### Vanilla SIR

# %%
beta = beta0
tsteps = 160
t = np.linspace(0, tsteps-1, 5*tsteps) #number of timesteps is tsteps

# %%
S, I, R = solve_sir(S0, I0, R0, N, beta, gamma, t)
J = beta*S

# %%
plt_title=''
plot_sir_withoutJ(S, I, R, t, plt_title, fig_name= 'plotsFinal/VanillaSIR.png')
plot_sir_withoutJ(S, I, R, t, plt_title, fig_name= 'plotsFinal/VanillaSIR.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### LV system

# %%
b = 1/N
d = gamma

# %%
x0 = beta0*S0
y0 = I0

# %%
X, Y = solve_lv(x0, y0, r, e, b, d, t)

# %%
plt_title=''
plot_lv(X, Y, t, plt_title, fig_name='plotsFinal/LV.png')
plot_lv(X, Y, t, plt_title, fig_name='plotsFinal/LV.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt_title = ''
plot_limit_cycle_color_gradient(X/Jstar, Y/Istar, plt_title = '', xlabel = 'p / p* (Normalised)',
                                ylabel= 'q / q* (Normalised)', fig_name ='plotsFinal/lv_limitingCycle.png', xyscale = 'linear',
                                start = 0, stop = len(X), eta = None )

plot_limit_cycle_color_gradient(X/Jstar, Y/Istar, plt_title = '', xlabel = 'p / p* (Normalised)',
                                ylabel= 'q / q* (Normalised)', fig_name ='plotsFinal/lv_limitingCycle.eps', xyscale = 'linear',
                                start = 0, stop = len(X), eta = None )

# %% [markdown]
# ### LV system equilibrium

# %%
y0 = r/e
x0 = d/b

# %%
X, Y = solve_lv(x0, y0, r, e, b, d, t)

# %%
plt_title = ''
plot_lv(X, Y, t, plt_title, fig_name='plotsFinal/LV-equilibrium.png')
plot_lv(X, Y, t, plt_title, fig_name='plotsFinal/LV-equilibrium.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### SIR-LV

# %%
I0 = 200000
S0 = N - I0 - R0
tsteps = 400
t = np.linspace(0, tsteps-1, 5*tsteps) #number of timesteps is tsteps

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-non_equlibrium_2.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-non_equlibrium_2.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name='plotsFinal/SIR-LV_beta_dynamics-non_equlibrium_2.png')
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name='plotsFinal/SIR-LV_beta_dynamics-non_equlibrium_2.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_beta_I(beta[:-2], I[:-2], t[:-2], Ilim = (-140000, 450000), betalim = (-0.2, 6), Istar=(r/e), plt_title='', fig_name='plotsFinal/SIR-LV_beta-I-non_equilibrium_2.png')
plot_beta_I(beta[:-2], I[:-2], t[:-2], Ilim = (-140000, 450000), betalim = (-0.2, 6), Istar=(r/e), plt_title='', fig_name='plotsFinal/SIR-LV_beta-I-non_equilibrium_2.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infectious',
#                  fig_name='SIR-LV-non-equilibrium_2_limit_cycle.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name ='plotsFinal/SIR-LV-non-equilibrium_2_limit_cycle.png', xyscale = 'linear',
                                start = 0, stop = len(J), eta = None )

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name ='plotsFinal/SIR-LV-non-equilibrium_2_limit_cycle.eps', xyscale = 'linear',
                                start = 0, stop = len(J), eta = None )

# %%
I0 = 100000
S0 = N - I0 - R0

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-non_equlibrium_1.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-non_equlibrium_1.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name='plotsFinal/SIR-LV_beta-I-non_equilibrium_1.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name='plotsFinal/SIR-LV_beta-I-non_equilibrium_1.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infectious',
#                  fig_name='SIR-LV-non-equilibrium_2_limit_cycle.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name ='plotsFinal/SIR-LV-non-equilibrium_1_limit_cycle.png', xyscale = 'linear',
                                start = 0, stop = len(X) , eta = None)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name ='plotsFinal/SIR-LV-non-equilibrium_1_limit_cycle.eps', xyscale = 'linear',
                                start = 0, stop = len(X), eta = None)

# %% [markdown]
# ### Equilibrium case

# %%
r = 3e-1
e = 2e-6
I0 = r/e
R0 = 200000
S0 = N - I0 - R0
beta0 = gamma*N/S0
tsteps = 403
t = np.linspace(0, tsteps-1, tsteps) #number of timesteps is tsteps

# %%
print(f'S0={S0}, I0={I0}, R0={R0}')

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-equlibrium.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics-equlibrium.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', betaMeanFlag = False, fig_name='plotsFinal/SIR-LV_beta-I-equilibrium.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', betaMeanFlag = False, fig_name='plotsFinal/SIR-LV_beta-I-equilibrium.eps')

# %%
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics_with_beta-equlibrium.png')
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name='plotsFinal/SIR-LV_dynamics_with_beta-equlibrium.eps')

# %% [markdown]
# ### SIR-LV with control

# %% [markdown]
# ### Re-initialise the variables

# %%
N = 13000000
R0 = 200000
I0 = 200000
r = 3e-1
e = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = gamma*N/S0
Istar = r/e
Jstar = gamma*N

# %% [markdown]
# ### eta = 1

# %%
eta = 1*gamma

# %%
tsteps = 400
t = np.linspace(0, tsteps-1, 5*tsteps)

# %%
S, I, R, beta = solve_sir_lv_control(S0, I0, R0, beta0, N, r, e, gamma, eta, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
# plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
# plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infected',
#                  fig_name=f'SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.eps', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

# %% [markdown]
# ### eta = 5

# %%
eta = 5*gamma

# %%
S, I, R, beta = solve_sir_lv_control(S0, I0, R0, beta0, N, r, e, gamma, eta, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name= f'plotsFinal/SIR-LV-control_dynamics_withBeta_eta_{eta}.png')
plot_sir_lv_withBeta(S, I, R, J, beta, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_withBeta_eta_{eta}.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infected',
#                  fig_name=f'SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J) , eta = eta)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.eps', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

# %% [markdown]
# ### eta = 10

# %%
eta = 10*gamma

# %%
S, I, R, beta = solve_sir_lv_control(S0, I0, R0, beta0, N, r, e, gamma, eta, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7), Istar = (r/e) ,  plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7),  Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infected',
#                  fig_name=f'SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.eps', xyscale = 'linear',
                                start = 0, stop = len(J)  , eta = eta)

# %%
eta = 15*gamma

# %%
S, I, R, beta = solve_sir_lv_control(S0, I0, R0, beta0, N, r, e, gamma, eta, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7),Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7),Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infected',
#                  fig_name=f'SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.eps', xyscale = 'linear',
                                start = 0, stop = len(J) , eta = eta)

# %%
eta = 20*gamma

# %%
S, I, R, beta = solve_sir_lv_control(S0, I0, R0, beta0, N, r, e, gamma, eta, t)
J = beta*S

# %%
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.png')
plot_sir_lv(S, I, R, J, t, plt_title='', fig_name=f'plotsFinal/SIR-LV-control_dynamics_eta_{eta}.eps')

# %%
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7),Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.png')
plot_beta_I(beta, I, t, Ilim = (-14000, 350000), betalim = (-0.2, 7),Istar = (r/e), plt_title='', fig_name=f'plotsFinal/SIR-LV_beta-I-control-non_equilibrium_eta_{eta}.eps')

# %%
# plot_limit_cycle(J/Jstar, I/Istar, plt_title='', 
#                  label='', 
#                  xlabel='betaS',
#                  ylabel='Infected',
#                  fig_name=f'SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png')

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J), eta = eta)

plot_limit_cycle_color_gradient(J/Jstar, I/Istar, plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', fig_name =f'plotsFinal/SIR-LV-control-non-equilibrium_limit_cycle_eta_{eta}.eps', xyscale = 'linear',
                                start = 0, stop = len(J) , eta = eta)

# %% [markdown]
# # Single Cycle Annotated

# %%
def getMaxBetaSTimes(betaS, tolerance):
    timestamps = []
    m = np.max(betaS)
    for i in range(len(betaS)):
        if(betaS[i]> m - tolerance):
            timestamps.append(i)
    remove = []
    for i in range(1, len(timestamps)):
        if(timestamps[i] - timestamps[i-1] == 1):
            if(betaS[timestamps[i-1]] > betaS[timestamps[i]] + 1):
                remove.append(timestamps[i])
            else:
                remove.append(timestamps[i-1])
    for i in remove:
        timestamps.remove(i)
    return timestamps

# %%
N = 13000000
R0 = 200000
I0 = 200000
r = 3e-1
e = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 400, 1601)

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
betaS = [beta[i]*S[i] for i in range(len(beta))]

# %%
timestamps = getMaxBetaSTimes(I, tolerance=1000)
print(timestamps)
T = []
for i in range(1, len(timestamps)):
    T.append(timestamps[i] - timestamps[i-1])

T = int(np.mean(T))
print(T/4)

# %%
west = 41
north = 41+80
south = 41+35
east = 41+61

# %%
X = [bs/(gamma*N) for bs in betaS]
Y = [i/(r/e) for i in I]

plot_single_limit_cycle_color_gradient(X, Y, startCycle = 41, Tperiod = T, factor = 4, NEWS =(north, east, west, south),
                                       plt_title='', xlabel = 'J / J* (Normalised)', ylabel = 'I / I* (Normalised)',
                                       fig_name = 'plotsFinal/LimitCycle_NEWS_annotated.png', xyscale = 'linear')

plot_single_limit_cycle_color_gradient(X, Y, startCycle = 41, Tperiod = T, factor = 4, NEWS =(north, east, west, south),
                                       plt_title='', xlabel = 'J / J* (Normalised)', ylabel = 'I / I* (Normalised)',
                                       fig_name = 'plotsFinal/LimitCycle_NEWS_annotated.eps', xyscale = 'linear')

# %%
N = 13000000
R0 = 200000
I0 = 200000
r = 3e-1
e = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
betaS = [beta[i]*S[i] for i in range(len(beta))]

# %%
west = int((41)/4)
north = int((41+80)/4)
south = int((41+35)/4)
east = int((41+61)/4)
west1 = int(41/4 + 26)

# %%
plot_sir_lv_oneCycle(S, I, R, betaS, beta, t, (north, east, west, south, west1), 27, fig_name = 'plotsFinal/SIR_oneCycle.png')
plot_sir_lv_oneCycle(S, I, R, betaS, beta, t, (north, east, west, south, west1), 27, fig_name = 'plotsFinal/SIR_oneCycle.eps')

# %%
plot_beta_I_oneCycle(beta, I, t, (north, east, west, south, west1), 27, fig_name = 'plotsFinal/betaI_oneCycle.png')
plot_beta_I_oneCycle(beta, I, t, (north, east, west, south, west1), 27, fig_name = 'plotsFinal/betaI_oneCycle.eps')

# %% [markdown]
# # SIR, delayedSIR, SEIR

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 13000000
I0, R0 = 1, 0
S0 = N - I0 - R0
beta, gamma = 0.4, 0.2
num_tsteps = 300

init = (S0, I0, R0)
delta_t = 0.001

# %%
S_SIR, I_SIR, R_SIR = solve_discrete_sir(init, beta, gamma, N, num_tsteps, delta_t=delta_t)
J_SIR = beta*S_SIR
t = np.linspace(0, num_tsteps-1, num_tsteps)

tau = 4
S_delayedSIR, I_delayedSIR, R_delayedSIR = solve_discrete_delayedSir(init, beta, gamma, N, num_tsteps, delta_t=delta_t, tau=tau)
J_delayedSIR = beta*S_delayedSIR
t = np.linspace(0, num_tsteps-1, num_tsteps)

# %%
N = 13000000
E0, I0, R0 = 0, 1, 0
S0 = N - I0 - R0 - E0
beta, gamma, sigma = 0.4, 0.2, 1./5
num_tsteps = 300

init = (S0, E0, I0, R0)
delta_t = 0.001
S_SEIR, E_SEIR, I_SEIR, R_SEIR = solve_discrete_SEIR(init, beta, gamma, sigma, N, num_tsteps, delta_t=delta_t)
J_SEIR = beta*S_SEIR
t = np.linspace(0, num_tsteps-1, num_tsteps)

# %%
plot_SIR_dSIR_SEIR(t, S_SIR, S_delayedSIR, S_SEIR, 
                   I_SIR, I_delayedSIR, I_SEIR, 
                   R_SIR, R_delayedSIR, R_SEIR, fig_name = './plotsFinal/SIR_dSIR_SEIR.png')

plot_SIR_dSIR_SEIR(t, S_SIR, S_delayedSIR, S_SEIR, 
                   I_SIR, I_delayedSIR, I_SEIR, 
                   R_SIR, R_delayedSIR, R_SEIR, fig_name = './plotsFinal/SIR_dSIR_SEIR.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize = (10, 8))
plt.plot(t, S_delayedSIR, color = 'orange', label = "S in delayed SIR")
plt.plot(t, I_delayedSIR, color = 'red', label = "I in delayed SIR")

plt.plot(t, S_SEIR, label = "S in SEIR", color = 'orange', linestyle = '--')
plt.plot(t, I_SEIR, label = "I in SEIR", color = 'red', linestyle = '--')

plt.plot(t, S_SIR, color = 'orange', label = "S in SIR", linestyle = 'dotted')
plt.plot(t, I_SIR, color = 'red', label = "I in SIR", linestyle = 'dotted')

plt.legend()
# plt.xticks(fontsize = 18)
# plt.yticks(fontsize = 18)
plt.xlabel("Time" , weight = 'bold')
plt.ylabel("Case Counts", weight = 'bold')
plt.grid(linestyle='dashdot', linewidth=0.5)
plt.savefig('./plotsFinal/SIR_dSIR_SEIR.png')
plt.savefig('./plotsFinal/SIR_dSIR_SEIR.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # delayedSIR Control

# %%
tau = 4
N = 13000000
R0 = 200000

r = 3e-1
e = 2e-6
I0 = 200000
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4


num_tsteps = 200

init = (S0, I0, R0, beta0)
delta_t = 0.0001
t = np.linspace(0, num_tsteps-1, num_tsteps)

# %%
eta = 1
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

plot_limit_cycle_color_gradient(J_delayedSIR[20:]/Jstar_delayedSIR, I_delayedSIR[20:]/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'linear',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %%
eta = 0.5*gamma
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %%
eta = 1*gamma
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %%
eta = 8*gamma
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %%
eta = 20*gamma
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %%
eta = 50*gamma
S_delayedSIR, I_delayedSIR, R_delayedSIR, beta_delayedSIR, Ws_eta0dot5 = solve_discrete_delayedSIR_LV_Control(init, gamma, N, num_tsteps, r, e, delta_t=delta_t, tau=tau, eta = eta)
J_delayedSIR = beta_delayedSIR*S_delayedSIR

# %%
Jstar_delayedSIR = gamma*N
Istar_delayedSIR = r/e
plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.eps', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

plot_limit_cycle_color_gradient(J_delayedSIR/Jstar_delayedSIR, I_delayedSIR/Istar_delayedSIR, 
                                plt_title = '', xlabel = 'J / J* (Normalised)',
                                ylabel= 'I / I* (Normalised)', 
                                fig_name =f'plotsFinal/delayed_SIR_eta_{eta}.png', xyscale = 'log',
                                start = 0, stop = len(J_delayedSIR), eta = eta)

# %% [markdown]
# # TPeriod Varying r

# %%
def getTimePeriodV2(series):
    timestamps = []
    for i in range(1, len(series)-1):
        if(series[i]>series[i-1] and series[i] > series[i+1]):
            timestamps.append(i)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    return T

# %%
N = 13000000
R0 = 200000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
t = np.linspace(0, 400, 401)
Istar = rstar/estar

# %%
import math
alphas = [0.01, 0.1, 0.2, 0.3, 0.4]
I0s = range(150000, 600000, 1000)
alphaI0 = dict()
for I0 in I0s:
    x = I0/Istar
    alphaI0[I0] = (x - math.log(x) - 1)

# %%
alphaI0

# %%
alphas = {0.01:173000, 0.03:190000, 0.1:228000, 0.3: 298000, 0.5:354000}

# %%
alphaT = dict()
for alpha, I0 in alphas.items():
    S0  = N - I0  - R0
    beta0 = gamma*N/S0
    rValues = [i*0.1 for i in range(1, 60)]
    alphaT[alpha] = []
    for r in rValues:
        e = r/Istar
        S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
        T = getTimePeriodV2(I[:300])
#         print(r,  T, I0)
        alphaT[alpha].append(T)

# %%
font = {'family':'serif','size':16}
plt.rc('font',**font)
plt.style.use('./presentation.mplstyle')

plt.figure(figsize = (10,8))
for alpha, T in alphaT.items():
    plt.plot(rValues, T, alpha = 1, label = r'$w_0/r = $' + str(alpha))
tprd = [(2*math.pi)/(math.sqrt(r * gamma)) for r in rValues]
plt.plot(rValues, tprd, linestyle = '--', alpha = 0.5, color = 'black', label = r'$ \frac{2*\pi}{\sqrt{r\gamma}} $')
plt.legend()
# plt.xticks(fontsize = 18)
# plt.yticks(fontsize = 18)
plt.xlabel(r"$r$", weight = 'bold', )
plt.ylabel(r"$T_{period}$", weight = 'bold', )
# plt.grid(linestyle='dashdot', linewidth=0.5)
plt.savefig('./plotsFinal/TperiodVsr_w0.png')
plt.savefig('./plotsFinal/TperiodVsr_w0.eps')

# %%
N = 13000000
R0 = 200000
I0 = 200000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)
Istar = rstar/estar

# %%
rValues = [rstar + float(i)/1000 for i in range(-200, 5000, 100)]
Tperiods_I0_200000 = []
for r in rValues:
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    betaS = [beta[i]*S[i] for i in range(len(beta))]
    timestamps = getMaxBetaSTimes(I[:400], tolerance = 10000)
#     print(r, timestamps)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    print(r, T)
    Tperiods_I0_200000.append(T)

# %%
N = 13000000
R0 = 200000
I0 = 100000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)
Istar = rstar/estar

Tperiods_I0_100000 = []
for r in rValues:
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    betaS = [beta[i]*S[i] for i in range(len(beta))]
    timestamps = getMaxBetaSTimes(I[:400], tolerance = 20000)
#     print(r, timestamps)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    print(r, T)
    Tperiods_I0_100000.append(T)

# %%
N = 13000000
R0 = 200000
I0 = 300000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)
Istar = rstar/estar

Tperiods_I0_300000 = []
for r in rValues:
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    betaS = [beta[i]*S[i] for i in range(len(beta))]
    timestamps = getMaxBetaSTimes(I[:400], tolerance = 50000)
#     print(r, timestamps)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    print(r, T)
    Tperiods_I0_300000.append(T)

# %%
N = 13000000
R0 = 200000
I0 = 50000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)
Istar = rstar/estar

Tperiods_I0_50000 = []
for r in rValues:
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    betaS = [beta[i]*S[i] for i in range(len(beta))]
    timestamps = getMaxBetaSTimes(I[:400], tolerance = 50000)
#     print(r, timestamps)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    print(r, T)
    Tperiods_I0_50000.append(T)

# %%
N = 13000000
R0 = 200000
I0 = 400000
rstar = 3e-1
estar = 2e-6
gamma = 0.2
S0 = N - I0 - R0
beta0 = 0.4
t = np.linspace(0, 800, 801)
Istar = rstar/estar

Tperiods_I0_400000 = []
for r in rValues:
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    betaS = [beta[i]*S[i] for i in range(len(beta))]
    timestamps = getMaxBetaSTimes(I[:400], tolerance = 50000)
#     print(r, timestamps)
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    print(r, T)
    Tperiods_I0_400000.append(T)

# %%
import math 
plt.plot(rValues, Tperiods_I0_50000, label = "I0 = 0.5e+5")
plt.plot(rValues, Tperiods_I0_100000, label = "I0 = 1e+5")
plt.plot(rValues, Tperiods_I0_200000, label = "I0 = 2e+5")
plt.plot(rValues, Tperiods_I0_300000, label = "I0 = 3e+5")
plt.plot(rValues, Tperiods_I0_400000, label = "I0 = 4e+5")

plt.grid(linestyle='dashdot', linewidth=0.5)
plt.xlabel("r")
plt.ylabel("Tperiod")
plt.legend()
plt.savefig('plotsFinal//TperiodVsr.png')

# %%
def getTimePeriodV2(series):
    timestamps = []
    for i in range(1, len(series)-1):
        if(series[i]>series[i-1] and series[i] > series[i+1]):
            timestamps.append(i)
#     print(timestamps)        
    T = []
    for i in range(1, len(timestamps)):
        T.append(timestamps[i] - timestamps[i-1])

    T = np.mean(T)
    return T

# %%
N = 13000000
R0 = 200000

rstar = 3e-1
estar = 2e-6
Istar = rstar/estar

gamma = 0.2

t = np.linspace(0, 400, 401)

# %%
I0 = 200000
float(I0)/Istar - math.log(float(I0)/Istar) - 1

# %%
import math
TPeriodDict = dict()
for I0 in range(30000, 300001, 10000):
    print(I0)
    alpha = float(I0)/Istar - math.log(float(I0)/Istar) - 1
    TPeriodDict[alpha] = dict()
    S0 = N - I0 - R0
    beta0 = gamma*N/S0
    for rx10 in range(1, 61):
        r = float(rx10)/10
        e = r/Istar
        S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
        T = getTimePeriodV2(I[:300])
        TPeriodDict[alpha][r] = T

# %%
import pandas as pd
df = pd.DataFrame.from_dict(TPeriodDict)

# %%
df.head()

# %%
df = df.sort_index(axis = 1)
df.head()

# %%
# df.to_csv('/Users/harsh.maheshwari/Desktop/covid-forecasting/betaControl/Code/Tperiod_r_alpha.csv')

# %%
I0 = 30000
print(I0)
alpha = float(I0)/Istar - math.log(float(I0)/Istar) - 1
TPeriodDict[alpha] = dict()
S0 = N - I0 - R0
beta0 = gamma*N/S0
for rx10 in range(1, 61):
    r = float(rx10)/10
    e = r/Istar
    S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)
    T = getTimePeriodV2(I[:50])
    print(r, T)
# Out:
# 30000
# 0.1 nan
# 0.2 nan
# 0.3 30.0
# 0.4 27.0
# 0.5 24.0
# 0.6 23.0
# 0.7 22.0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.8 21.0
# 0.9 20.5
# 1.0 20.0
# 1.1 19.0
# 1.2 19.0
# 1.3 18.5
# 1.4 18.5
# 1.5 18.0
# 1.6 17.5
# 1.7 18.0
# 1.8 17.5
# 1.9 17.5
# 2.0 17.0
# 2.1 17.0
# 2.2 17.0
# 2.3 16.5
# 2.4 16.5
# 2.5 16.5
# 2.6 16.0
# 2.7 16.0
# 2.8 16.5
# 2.9 16.5
# 3.0 16.0
# 3.1 16.0
# 3.2 16.0
# 3.3 16.0
# 3.4 16.0
# 3.5 16.0
# 3.6 15.5
# 3.7 15.5
# 3.8 15.5
# 3.9 15.5
# 4.0 15.333333333333334
# 4.1 15.333333333333334
# 4.2 15.333333333333334
# 4.3 15.333333333333334
# 4.4 15.333333333333334
# 4.5 15.333333333333334
# 4.6 15.0
# 4.7 15.333333333333334
# 4.8 15.0
# 4.9 15.0
# 5.0 6.285714285714286
# 5.1 6.428571428571429
# 5.2 4.888888888888889
# 5.3 5.111111111111111
# 5.4 4.6
# 5.5 4.0
# 5.6 4.888888888888889
# 5.7 15.0
# 5.8 4.181818181818182
# 5.9 5.375
# 6.0 4.888888888888889

# %%
betaS = [beta[i]*S[i] for i in range(len(S))]

# %%
plt.plot(t[:100], S[:100])

# %%
beta0
# Out:
# 0.20360219263899765

# %%
N = 13000000
R0 = 200000
I0 = 30000
rstar = 3e-1
estar = 2e-6
Istar = rstar/estar
r  = 5.1
e = r/Istar
gamma = 0.2
print(r, e)
t = np.linspace(0, 400, 401)
# Out:
# 5.1 3.4e-05

# %%
S, I, R, beta = solve_sir_lv(S0, I0, R0, beta0, N, r, e, gamma, t)

# %%
start = 0
stop  = 20
plt.plot(t[start:stop], S[start:stop])
plt.plot(t[start:stop], I[start:stop])
plt.plot(t[start:stop], R[start:stop])

# %%
plt.plot(t[start:stop], beta[start:stop])
